# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | champerico
# Processing Record 2 of Set 1 | hobyo
# Processing Record 3 of Set 1 | ambon
# Processing Record 4 of Set 1 | alcaniz
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | missoula
# Processing Record 10 of Set 1 | howard springs
# Processing Record 11 of Set 1 | tallahassee
# Processing Record 12 of Set 1 | saint anthony
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | cukai
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | viedma
# Processing Record 20 of Set 1 | kamina
# Processing Record 21 of Set 1 | vasilyevskiy mokh
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | progreso
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | makakilo city
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | eyl
# Processing Record 29 of Set 1 | poum
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | lipari
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | cape elizabeth
# City not found. Skipping...
# Processing Record 36 of Set 1 | baykit
# Processing Record 37 of Set 1 | pochutla
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | sisimiut
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | havre-saint-pierre
# Processing Record 42 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 1 | nouadhibou
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | yuli
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | sawakin
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | taoudenni
# Processing Record 15 of Set 2 | euskirchen
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | aklavik
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | egvekinot
# Processing Record 22 of Set 2 | wuwei
# Processing Record 23 of Set 2 | thinadhoo
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | cape coast
# Processing Record 30 of Set 2 | lorengau
# Processing Record 31 of Set 2 | miraflores
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | caibarien
# Processing Record 34 of Set 2 | lethem
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | mattru
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | kerrville
# Processing Record 39 of Set 2 | koslan
# Processing Record 40 of Set 2 | altamira
# Processing Record 41 of Set 2 | houma
# Processing Record 42 of Set 2 | richards bay
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | parrita
# Processing Record 45 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | murmansk
# Processing Record 48 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 2 | kembe
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | nanortalik
# Processing Record 2 of Set 3 | olinda
# Processing Record 3 of Set 3 | harper
# Processing Record 4 of Set 3 | moncao
# Processing Record 5 of Set 3 | gawan
# Processing Record 6 of Set 3 | xining
# Processing Record 7 of Set 3 | pontarlier
# Processing Record 8 of Set 3 | klaksvik
# Processing Record 9 of Set 3 | waddan
# Processing Record 10 of Set 3 | port hardy
# Processing Record 11 of Set 3 | kiama
# Processing Record 12 of Set 3 | benguela
# Processing Record 13 of Set 3 | narsaq
# Processing Record 14 of Set 3 | worthington
# Processing Record 15 of Set 3 | tautira
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | bosaso
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | hoquiam
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | verkhnyaya inta
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | rauma
# Processing Record 26 of Set 3 | maldonado
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | mandera
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | gewane
# Processing Record 31 of Set 3 | hay river
# Processing Record 32 of Set 3 | muisne
# Processing Record 33 of Set 3 | talaya
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | pangoa
# Processing Record 36 of Set 3 | mariel
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | usinsk
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | hami
# Processing Record 41 of Set 3 | puerto escondido
# Processing Record 42 of Set 3 | neuquen
# Processing Record 43 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 3 | oktyabrskiy
# Processing Record 45 of Set 3 | qui nhon
# Processing Record 46 of Set 3 | hendek
# Processing Record 47 of Set 3 | soc trang
# Processing Record 48 of Set 3 | barra patuca
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | san buenaventura
# Processing Record 2 of Set 4 | agutaya
# Processing Record 3 of Set 4 | muros
# Processing Record 4 of Set 4 | trinidad
# Processing Record 5 of Set 4 | bonfim
# Processing Record 6 of Set 4 | peterhead
# Processing Record 7 of Set 4 | nkowakowa
# Processing Record 8 of Set 4 | biak
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | golden gate
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | churachandpur
# Processing Record 13 of Set 4 | albany
# Processing Record 14 of Set 4 | kamenka
# Processing Record 15 of Set 4 | porto novo
# Processing Record 16 of Set 4 | dunedin
# Processing Record 17 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 4 | san antonio
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | mocuba
# Processing Record 21 of Set 4 | pitlochry
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | nuuk
# Processing Record 25 of Set 4 | corpus christi
# Processing Record 26 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | maragogi
# Processing Record 29 of Set 4 | taltal
# Processing Record 30 of Set 4 | laizhou
# Processing Record 31 of Set 4 | surovikino
# Processing Record 32 of Set 4 | braila
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | hasaki
# Processing Record 35 of Set 4 | mongoumba
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | bingol
# Processing Record 38 of Set 4 | emba
# Processing Record 39 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | republic
# Processing Record 43 of Set 4 | saint-pierre
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | vanimo
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | tharad
# Processing Record 48 of Set 4 | vangaindrano
# Processing Record 49 of Set 4 | kutum
# Processing Record 50 of Set 4 | kautokeino
# Processing Record 1 of Set 5 | itoman
# Processing Record 2 of Set 5 | salme
# Processing Record 3 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 5 | olafsvik
# Processing Record 5 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | qostanay
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | walcz
# Processing Record 12 of Set 5 | grafton
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | port blair
# Processing Record 15 of Set 5 | karaton
# Processing Record 16 of Set 5 | saint-leu
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 5 | marrakesh
# Processing Record 20 of Set 5 | inhambane
# Processing Record 21 of Set 5 | havelock
# Processing Record 22 of Set 5 | dudinka
# Processing Record 23 of Set 5 | floro
# Processing Record 24 of Set 5 | moron
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | belton
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | batagay
# Processing Record 29 of Set 5 | rocha
# Processing Record 30 of Set 5 | yenagoa
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | saint austell
# Processing Record 33 of Set 5 | acapulco
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | yar-sale
# Processing Record 36 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 5 | sao miguel do araguaia
# Processing Record 38 of Set 5 | kinsale
# Processing Record 39 of Set 5 | breytovo
# Processing Record 40 of Set 5 | tairua
# Processing Record 41 of Set 5 | urcos
# Processing Record 42 of Set 5 | kargasok
# Processing Record 43 of Set 5 | sao filipe
# Processing Record 44 of Set 5 | souillac
# Processing Record 45 of Set 5 | praia
# Processing Record 46 of Set 5 | vardo
# Processing Record 47 of Set 5 | mujiayingzi
# Processing Record 48 of Set 5 | bethel
# Processing Record 49 of Set 5 | naze
# Processing Record 50 of Set 5 | palmas bellas
# Processing Record 1 of Set 6 | junin
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | herat
# Processing Record 4 of Set 6 | ixtapa
# Processing Record 5 of Set 6 | longyearbyen
# Processing Record 6 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 7 of Set 6 | ancud
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | pontiac
# Processing Record 10 of Set 6 | mangrol
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | ponta delgada
# Processing Record 13 of Set 6 | novikovo
# Processing Record 14 of Set 6 | opuwo
# Processing Record 15 of Set 6 | cidreira
# Processing Record 16 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | santa maria
# Processing Record 19 of Set 6 | suruc
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | nynashamn
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | bambous virieux
# Processing Record 26 of Set 6 | qaanaaq
# Processing Record 27 of Set 6 | miyang
# Processing Record 28 of Set 6 | tiksi
# Processing Record 29 of Set 6 | berlevag
# Processing Record 30 of Set 6 | aberdeen
# Processing Record 31 of Set 6 | iwanai
# Processing Record 32 of Set 6 | pacific grove
# Processing Record 33 of Set 6 | whyalla
# Processing Record 34 of Set 6 | grand gaube
# Processing Record 35 of Set 6 | aksarka
# Processing Record 36 of Set 6 | jaru
# Processing Record 37 of Set 6 | tutoia
# Processing Record 38 of Set 6 | nabagram
# Processing Record 39 of Set 6 | semnan
# Processing Record 40 of Set 6 | pacifica
# Processing Record 41 of Set 6 | altay
# Processing Record 42 of Set 6 | dawei
# Processing Record 43 of Set 6 | zavodouspenskoye
# Processing Record 44 of Set 6 | mwene-ditu
# Processing Record 45 of Set 6 | sarkand
# Processing Record 46 of Set 6 | cozumel
# Processing Record 47 of Set 6 | tolaga bay
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | manali
# Processing Record 50 of Set 6 | ye
# City not found. Skipping...
# Processing Record 1 of Set 7 | cootamundra
# Processing Record 2 of Set 7 | gasa
# Processing Record 3 of Set 7 | mahebourg
# Processing Record 4 of Set 7 | atambua
# Processing Record 5 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 7 | diplo
# Processing Record 7 of Set 7 | portland
# Processing Record 8 of Set 7 | eten
# Processing Record 9 of Set 7 | broken hill
# Processing Record 10 of Set 7 | nishihara
# Processing Record 11 of Set 7 | burns lake
# Processing Record 12 of Set 7 | bluffton
# Processing Record 13 of Set 7 | ilulissat
# Processing Record 14 of Set 7 | itarema
# Processing Record 15 of Set 7 | nayoro
# Processing Record 16 of Set 7 | alta floresta
# Processing Record 17 of Set 7 | chino valley
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | saint-francois
# Processing Record 22 of Set 7 | zhigansk
# Processing Record 23 of Set 7 | purworejo
# Processing Record 24 of Set 7 | milkovo
# Processing Record 25 of Set 7 | puerto padre
# Processing Record 26 of Set 7 | stornoway
# Processing Record 27 of Set 7 | birjand
# Processing Record 28 of Set 7 | bagotville
# Processing Record 29 of Set 7 | listowel
# Processing Record 30 of Set 7 | khatanga
# Processing Record 31 of Set 7 | leningradskiy
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | solnechnyy
# Processing Record 34 of Set 7 | kaya
# Processing Record 35 of Set 7 | la serena
# Processing Record 36 of Set 7 | greensburg
# Processing Record 37 of Set 7 | kenai
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | thaton
# Processing Record 41 of Set 7 | dalmeny
# Processing Record 42 of Set 7 | asopos
# Processing Record 43 of Set 7 | port-gentil
# Processing Record 44 of Set 7 | tevriz
# Processing Record 45 of Set 7 | kungurtug
# Processing Record 46 of Set 7 | husavik
# Processing Record 47 of Set 7 | shieli
# Processing Record 48 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | asfi
# Processing Record 50 of Set 7 | lahaina
# Processing Record 1 of Set 8 | dhadar
# Processing Record 2 of Set 8 | kingman
# Processing Record 3 of Set 8 | santa rosa
# Processing Record 4 of Set 8 | kidal
# Processing Record 5 of Set 8 | bouca
# Processing Record 6 of Set 8 | burica
# City not found. Skipping...
# Processing Record 7 of Set 8 | scarborough
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | saint-denis
# Processing Record 10 of Set 8 | tselinnoye
# Processing Record 11 of Set 8 | rio brilhante
# Processing Record 12 of Set 8 | la rioja
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | ventspils
# Processing Record 15 of Set 8 | praia da vitoria
# Processing Record 16 of Set 8 | san ignacio
# Processing Record 17 of Set 8 | san jose
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | boden
# Processing Record 20 of Set 8 | katherine
# Processing Record 21 of Set 8 | bandarbeyla
# Processing Record 22 of Set 8 | te anau
# Processing Record 23 of Set 8 | wasilla
# Processing Record 24 of Set 8 | novokizhinginsk
# Processing Record 25 of Set 8 | shentala
# Processing Record 26 of Set 8 | lincoln
# Processing Record 27 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 8 | bukavu
# Processing Record 29 of Set 8 | tigil
# Processing Record 30 of Set 8 | chone
# Processing Record 31 of Set 8 | batemans bay
# Processing Record 32 of Set 8 | kolda
# Processing Record 33 of Set 8 | yumen
# Processing Record 34 of Set 8 | andenes
# Processing Record 35 of Set 8 | namibe
# Processing Record 36 of Set 8 | muroto
# Processing Record 37 of Set 8 | san francisco
# Processing Record 38 of Set 8 | chapais
# Processing Record 39 of Set 8 | motala
# Processing Record 40 of Set 8 | kavieng
# Processing Record 41 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 8 | aranos
# Processing Record 43 of Set 8 | huarmey
# Processing Record 44 of Set 8 | farmington
# Processing Record 45 of Set 8 | dhidhdhoo
# Processing Record 46 of Set 8 | mirnyy
# Processing Record 47 of Set 8 | tazovskiy
# Processing Record 48 of Set 8 | buarcos
# Processing Record 49 of Set 8 | jalingo
# Processing Record 50 of Set 8 | abonnema
# Processing Record 1 of Set 9 | barkhan
# Processing Record 2 of Set 9 | vulcan
# Processing Record 3 of Set 9 | saskylakh
# Processing Record 4 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 9 | tual
# Processing Record 6 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 9 | merauke
# Processing Record 8 of Set 9 | san cristobal
# Processing Record 9 of Set 9 | sokoto
# Processing Record 10 of Set 9 | lifford
# Processing Record 11 of Set 9 | quatre cocos
# Processing Record 12 of Set 9 | edd
# Processing Record 13 of Set 9 | asau
# Processing Record 14 of Set 9 | xiaoweizhai
# Processing Record 15 of Set 9 | novo aripuana
# Processing Record 16 of Set 9 | kamaishi
# Processing Record 17 of Set 9 | kaitangata
# Processing Record 18 of Set 9 | finschhafen
# Processing Record 19 of Set 9 | mandalgovi
# Processing Record 20 of Set 9 | ruwi
# Processing Record 21 of Set 9 | biltine
# Processing Record 22 of Set 9 | dukat
# Processing Record 23 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 9 | basco
# Processing Record 25 of Set 9 | kon tum
# Processing Record 26 of Set 9 | guerrero negro
# Processing Record 27 of Set 9 | clifton
# Processing Record 28 of Set 9 | ena
# Processing Record 29 of Set 9 | tocopilla
# Processing Record 30 of Set 9 | kuching
# Processing Record 31 of Set 9 | wajid
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | krasnoselkup
# Processing Record 34 of Set 9 | kavaratti
# Processing Record 35 of Set 9 | aksu
# Processing Record 36 of Set 9 | nhulunbuy
# Processing Record 37 of Set 9 | nome
# Processing Record 38 of Set 9 | aloleng
# Processing Record 39 of Set 9 | ribeira grande
# Processing Record 40 of Set 9 | high level
# Processing Record 41 of Set 9 | surt
# Processing Record 42 of Set 9 | shirokiy
# Processing Record 43 of Set 9 | omsukchan
# Processing Record 44 of Set 9 | micomeseng
# Processing Record 45 of Set 9 | alekseyevsk
# Processing Record 46 of Set 9 | mariestad
# Processing Record 47 of Set 9 | isangel
# Processing Record 48 of Set 9 | antsohihy
# Processing Record 49 of Set 9 | puerto colombia
# Processing Record 50 of Set 9 | kem
# Processing Record 1 of Set 10 | rabak
# Processing Record 2 of Set 10 | timra
# Processing Record 3 of Set 10 | akom
# Processing Record 4 of Set 10 | puri
# Processing Record 5 of Set 10 | yambio
# Processing Record 6 of Set 10 | tilichiki
# Processing Record 7 of Set 10 | sao gabriel da cachoeira
# Processing Record 8 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | barcelona
# Processing Record 10 of Set 10 | dolzhanskaya
# Processing Record 11 of Set 10 | haapiti
# Processing Record 12 of Set 10 | saldanha
# Processing Record 13 of Set 10 | sergeyevka
# Processing Record 14 of Set 10 | irtyshskiy
# Processing Record 15 of Set 10 | popondetta
# Processing Record 16 of Set 10 | kholtoson
# Processing Record 17 of Set 10 | bathsheba
# Processing Record 18 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 19 of Set 10 | mariental
# Processing Record 20 of Set 10 | mount vernon
# Processing Record 21 of Set 10 | petrovskaya
# Processing Record 22 of Set 10 | vryburg
# Processing Record 23 of Set 10 | podosinovets
# Processing Record 24 of Set 10 | gat
# Processing Record 25 of Set 10 | krasnyy profintern
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | grindavik
# Processing Record 28 of Set 10 | isparta
# Processing Record 29 of Set 10 | clyde river
# Processing Record 30 of Set 10 | yarmouth
# Processing Record 31 of Set 10 | skjervoy
# Processing Record 32 of Set 10 | hvide sande
# Processing Record 33 of Set 10 | warrington
# Processing Record 34 of Set 10 | meulaboh
# Processing Record 35 of Set 10 | carazinho
# Processing Record 36 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 10 | machaneng
# Processing Record 38 of Set 10 | fare
# Processing Record 39 of Set 10 | yulara
# Processing Record 40 of Set 10 | moroni
# Processing Record 41 of Set 10 | coihaique
# Processing Record 42 of Set 10 | vaxjo
# Processing Record 43 of Set 10 | itaborai
# Processing Record 44 of Set 10 | karasuk
# Processing Record 45 of Set 10 | zaragoza
# Processing Record 46 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 10 | rio de janeiro
# Processing Record 48 of Set 10 | kongoussi
# Processing Record 49 of Set 10 | lensk
# Processing Record 50 of Set 10 | chara
# Processing Record 1 of Set 11 | kouroussa
# Processing Record 2 of Set 11 | aykhal
# Processing Record 3 of Set 11 | fort myers beach
# Processing Record 4 of Set 11 | comodoro rivadavia
# Processing Record 5 of Set 11 | tarko-sale
# Processing Record 6 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 11 | lavrentiya
# Processing Record 8 of Set 11 | general roca
# Processing Record 9 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 11 | weligama
# Processing Record 11 of Set 11 | manakara
# Processing Record 12 of Set 11 | takaka
# Processing Record 13 of Set 11 | idanre
# Processing Record 14 of Set 11 | saraikela
# Processing Record 15 of Set 11 | kupang
# Processing Record 16 of Set 11 | camana
# Processing Record 17 of Set 11 | orcopampa
# Processing Record 18 of Set 11 | polunochnoye
# Processing Record 19 of Set 11 | mantua
# Processing Record 20 of Set 11 | sola
# Processing Record 21 of Set 11 | phatthalung
# Processing Record 22 of Set 11 | mago
# Processing Record 23 of Set 11 | goderich
# Processing Record 24 of Set 11 | the valley
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | semey
# Processing Record 27 of Set 11 | shingu
# Processing Record 28 of Set 11 | patnos
# Processing Record 29 of Set 11 | lakes entrance
# Processing Record 30 of Set 11 | arlit
# Processing Record 31 of Set 11 | svetlyy
# Processing Record 32 of Set 11 | cocorit
# Processing Record 33 of Set 11 | edson
# Processing Record 34 of Set 11 | tuntum
# Processing Record 35 of Set 11 | sayyan
# Processing Record 36 of Set 11 | westerland
# Processing Record 37 of Set 11 | beyneu
# Processing Record 38 of Set 11 | sinnamary
# Processing Record 39 of Set 11 | aras
# Processing Record 40 of Set 11 | ornskoldsvik
# Processing Record 41 of Set 11 | belaya gora
# Processing Record 42 of Set 11 | karpogory
# Processing Record 43 of Set 11 | lebowakgomo
# Processing Record 44 of Set 11 | shawnee
# Processing Record 45 of Set 11 | belmonte
# Processing Record 46 of Set 11 | molokovo
# Processing Record 47 of Set 11 | vestmannaeyjar
# Processing Record 48 of Set 11 | chihuahua
# Processing Record 49 of Set 11 | guayata
# Processing Record 50 of Set 11 | oranjestad
# Processing Record 1 of Set 12 | algodones
# Processing Record 2 of Set 12 | palana
# Processing Record 3 of Set 12 | marzuq
# Processing Record 4 of Set 12 | ipira
# Processing Record 5 of Set 12 | kathmandu
# Processing Record 6 of Set 12 | laramie
# Processing Record 7 of Set 12 | taperoa
# Processing Record 8 of Set 12 | tokzar
# City not found. Skipping...
# Processing Record 9 of Set 12 | moussoro
# Processing Record 10 of Set 12 | ulladulla
# Processing Record 11 of Set 12 | whitehorse
# Processing Record 12 of Set 12 | wewak
# Processing Record 13 of Set 12 | beringovskiy
# Processing Record 14 of Set 12 | colesberg
# Processing Record 15 of Set 12 | honiara
# Processing Record 16 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 17 of Set 12 | rakhiv
# Processing Record 18 of Set 12 | nicoya
# Processing Record 19 of Set 12 | bam
# Processing Record 20 of Set 12 | korla
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | dakar
# Processing Record 23 of Set 12 | port moresby
# Processing Record 24 of Set 12 | dingle
# Processing Record 25 of Set 12 | okhotsk
# Processing Record 26 of Set 12 | acari
# Processing Record 27 of Set 12 | vao
# Processing Record 28 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | garmsar
# Processing Record 30 of Set 12 | hualmay
# Processing Record 31 of Set 12 | silistea
# Processing Record 32 of Set 12 | chodavaram
# Processing Record 33 of Set 12 | klyuchi
# Processing Record 34 of Set 12 | guanica
# Processing Record 35 of Set 12 | cota
# Processing Record 36 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 37 of Set 12 | tabou
# Processing Record 38 of Set 12 | bengkulu
# Processing Record 39 of Set 12 | mbanza-ngungu
# Processing Record 40 of Set 12 | wamba
# Processing Record 41 of Set 12 | daura
# Processing Record 42 of Set 12 | zdvinsk
# Processing Record 43 of Set 12 | jiwani
# Processing Record 44 of Set 12 | mayumba
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 12 | huilong
# Processing Record 48 of Set 12 | laguna
# Processing Record 49 of Set 12 | andros
# Processing Record 50 of Set 12 | ouango
# Processing Record 1 of Set 13 | valleyview
# Processing Record 2 of Set 13 | abu samrah
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | russell
# Processing Record 5 of Set 13 | kaeo
# Processing Record 6 of Set 13 | riyadh
# Processing Record 7 of Set 13 | lata
# Processing Record 8 of Set 13 | cody
# Processing Record 9 of Set 13 | am timan
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | puebla
# Processing Record 12 of Set 13 | new glasgow
# Processing Record 13 of Set 13 | alice springs
# Processing Record 14 of Set 13 | qaqortoq
# Processing Record 15 of Set 13 | bull savanna
# Processing Record 16 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 13 | camacha
# Processing Record 18 of Set 13 | belyy yar
# Processing Record 19 of Set 13 | sesheke
# Processing Record 20 of Set 13 | luba
# Processing Record 21 of Set 13 | kattivakkam
# Processing Record 22 of Set 13 | quibor
# Processing Record 23 of Set 13 | yakovlevka
# Processing Record 24 of Set 13 | felanitx
# Processing Record 25 of Set 13 | uige
# Processing Record 26 of Set 13 | fort saint james
# Processing Record 27 of Set 13 | ekhabi
# Processing Record 28 of Set 13 | dunmore town
# Processing Record 29 of Set 13 | tuyen quang
# Processing Record 30 of Set 13 | mananjary
# Processing Record 31 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 32 of Set 13 | blackwater
# Processing Record 33 of Set 13 | izumo
# Processing Record 34 of Set 13 | soyo
# Processing Record 35 of Set 13 | lucapa
# Processing Record 36 of Set 13 | alcobendas
# Processing Record 37 of Set 13 | araouane
# Processing Record 38 of Set 13 | sambava
# Processing Record 39 of Set 13 | troitsko-pechorsk
# Processing Record 40 of Set 13 | babayurt
# Processing Record 41 of Set 13 | qiqihar
# Processing Record 42 of Set 13 | williams lake
# Processing Record 43 of Set 13 | songjianghe
# Processing Record 44 of Set 13 | marsa matruh
# Processing Record 45 of Set 13 | luanda
# Processing Record 46 of Set 13 | ketchikan
# Processing Record 47 of Set 13 | takapau
# Processing Record 48 of Set 13 | waingapu
# Processing Record 49 of Set 13 | bartica
# Processing Record 50 of Set 13 | bagdarin
# Processing Record 1 of Set 14 | gravelbourg
# Processing Record 2 of Set 14 | mareeba
# Processing Record 3 of Set 14 | putla
# City not found. Skipping...
# Processing Record 4 of Set 14 | makaryev
# Processing Record 5 of Set 14 | fasa
# Processing Record 6 of Set 14 | kihei
# Processing Record 7 of Set 14 | diego de almagro
# Processing Record 8 of Set 14 | uvalde
# Processing Record 9 of Set 14 | kazachinskoye
# Processing Record 10 of Set 14 | jumla
# Processing Record 11 of Set 14 | pandan
# Processing Record 12 of Set 14 | kuusamo
# Processing Record 13 of Set 14 | prachuap khiri khan
# Processing Record 14 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 14 | magnolia
# Processing Record 16 of Set 14 | jieshi
# Processing Record 17 of Set 14 | zaykovo
# Processing Record 18 of Set 14 | adrar
# Processing Record 19 of Set 14 | santa cruz cabralia
# Processing Record 20 of Set 14 | jalu
# Processing Record 21 of Set 14 | kitui
# Processing Record 22 of Set 14 | cockburn town
# Processing Record 23 of Set 14 | sahuaripa
# Processing Record 24 of Set 14 | lanigan
# Processing Record 25 of Set 14 | walvis bay
# Processing Record 26 of Set 14 | matagami
# Processing Record 27 of Set 14 | faya
# Processing Record 28 of Set 14 | pedernales
# Processing Record 29 of Set 14 | menongue
# Processing Record 30 of Set 14 | esperance
# Processing Record 31 of Set 14 | teguldet
# Processing Record 32 of Set 14 | sterling
# Processing Record 33 of Set 14 | kurilsk
# Processing Record 34 of Set 14 | katy
# Processing Record 35 of Set 14 | kununurra
# Processing Record 36 of Set 14 | isiro
# Processing Record 37 of Set 14 | coari
# Processing Record 38 of Set 14 | sherlovaya gora
# Processing Record 39 of Set 14 | karlskoga
# Processing Record 40 of Set 14 | ola
# Processing Record 41 of Set 14 | miri
# Processing Record 42 of Set 14 | labuhan
# Processing Record 43 of Set 14 | gudari
# Processing Record 44 of Set 14 | fairbanks
# Processing Record 45 of Set 14 | cedar city
# Processing Record 46 of Set 14 | chirongui
# Processing Record 47 of Set 14 | ekuvukeni
# Processing Record 48 of Set 14 | skerries
# Processing Record 49 of Set 14 | deori
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | inirida
# Processing Record 2 of Set 15 | avera
# Processing Record 3 of Set 15 | waynesville
# Processing Record 4 of Set 15 | santiago
# Processing Record 5 of Set 15 | codrington
# Processing Record 6 of Set 15 | morro bay
# Processing Record 7 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 15 | ust-karsk
# Processing Record 9 of Set 15 | mutis
# Processing Record 10 of Set 15 | buin
# Processing Record 11 of Set 15 | lagoa vermelha
# Processing Record 12 of Set 15 | san-pedro
# Processing Record 13 of Set 15 | esmeraldas
# Processing Record 14 of Set 15 | burdur
# Processing Record 15 of Set 15 | arrifes
# Processing Record 16 of Set 15 | batticaloa
# Processing Record 17 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 15 | ettenheim
# Processing Record 19 of Set 15 | evensk
# Processing Record 20 of Set 15 | oksfjord
# Processing Record 21 of Set 15 | mount isa
# Processing Record 22 of Set 15 | verkh-usugli
# Processing Record 23 of Set 15 | linjiang
# Processing Record 24 of Set 15 | sand springs
# Processing Record 25 of Set 15 | katastarion
# Processing Record 26 of Set 15 | luis correia
# Processing Record 27 of Set 15 | san carlos
# Processing Record 28 of Set 15 | deyang
# Processing Record 29 of Set 15 | turmalina
# Processing Record 30 of Set 15 | garowe
# Processing Record 31 of Set 15 | harlingen
# Processing Record 32 of Set 15 | luau
# Processing Record 33 of Set 15 | marseille
# Processing Record 34 of Set 15 | port lincoln
# Processing Record 35 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 15 | vila franca do campo
# Processing Record 37 of Set 15 | koumac
# Processing Record 38 of Set 15 | champasak
# Processing Record 39 of Set 15 | staryy nadym
# Processing Record 40 of Set 15 | matamoros
# Processing Record 41 of Set 15 | ibra
# Processing Record 42 of Set 15 | manjeshwar
# Processing Record 43 of Set 15 | dinghai
# Processing Record 44 of Set 15 | carbondale
# Processing Record 45 of Set 15 | umm kaddadah
# Processing Record 46 of Set 15 | maridi
# Processing Record 47 of Set 15 | el tigre
# Processing Record 48 of Set 15 | gavalou
# Processing Record 49 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 15 | tezu
# Processing Record 1 of Set 16 | phan thiet
# Processing Record 2 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 16 | saryagash
# Processing Record 4 of Set 16 | martapura
# Processing Record 5 of Set 16 | lasa
# Processing Record 6 of Set 16 | carauari
# Processing Record 7 of Set 16 | kruisfontein
# Processing Record 8 of Set 16 | deoria
# Processing Record 9 of Set 16 | taraz
# Processing Record 10 of Set 16 | cuenca
# Processing Record 11 of Set 16 | koulamoutou
# Processing Record 12 of Set 16 | albemarle
# Processing Record 13 of Set 16 | ahtopol
# Processing Record 14 of Set 16 | benjamin aceval
# Processing Record 15 of Set 16 | trincomalee
# Processing Record 16 of Set 16 | ganzhou
# Processing Record 17 of Set 16 | marondera
# Processing Record 18 of Set 16 | nanyang
# Processing Record 19 of Set 16 | besikduzu
# Processing Record 20 of Set 16 | deputatskiy
# Processing Record 21 of Set 16 | pafos
# Processing Record 22 of Set 16 | otradnoye
# Processing Record 23 of Set 16 | matay
# Processing Record 24 of Set 16 | inta
# Processing Record 25 of Set 16 | itaituba
# Processing Record 26 of Set 16 | daru
# Processing Record 27 of Set 16 | concepcion del oro
# Processing Record 28 of Set 16 | valdivia
# Processing Record 29 of Set 16 | nanzhang
# Processing Record 30 of Set 16 | mogadishu
# Processing Record 31 of Set 16 | listica
# City not found. Skipping...
# Processing Record 32 of Set 16 | amarante do maranhao
# Processing Record 33 of Set 16 | vikhorevka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 724

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Champerico      GT  14.3000  -91.9167     82.76        74          91
# 1       Hobyo      SO   5.3505   48.5268     75.43        77          76
# 2       Ambon      ID  -3.6954  128.1814     86.14        70          40
# 3     Alcaniz      ES  41.0500   -0.1333     67.42        61          87
# 4       Vaini      TO -21.2000 -175.2000     78.96        83          20
#
#    Wind Speed Current Description
# 0        3.80     overcast clouds
# 1       22.79       broken clouds
# 2        5.75    scattered clouds
# 3       11.36       moderate rain
# 4        8.05          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
