# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clarence town
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | maragogi
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | itamaraca
# Processing Record 7 of Set 1 | champerico
# Processing Record 8 of Set 1 | okha
# Processing Record 9 of Set 1 | konevo
# Processing Record 10 of Set 1 | naze
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | darnah
# Processing Record 13 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | geraldton
# Processing Record 17 of Set 1 | touros
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | coihaique
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | mukhen
# Processing Record 22 of Set 1 | warrnambool
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | janauba
# Processing Record 25 of Set 1 | yuyao
# Processing Record 26 of Set 1 | limbe
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | jijiang
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | lasa
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | suntar
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | mwinilunga
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | waipawa
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | harper
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | pangnirtung
# Processing Record 50 of Set 1 | hambantota
# Processing Record 1 of Set 2 | salinas
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | burias
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | pedernales
# Processing Record 8 of Set 2 | selfoss
# Processing Record 9 of Set 2 | mama
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | atambua
# Processing Record 12 of Set 2 | filingue
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 2 | chifeng
# Processing Record 16 of Set 2 | saint-augustin
# Processing Record 17 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 2 | mutsu
# Processing Record 19 of Set 2 | ashtian
# Processing Record 20 of Set 2 | athni
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | de-kastri
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | fort nelson
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | xining
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | anjozorobe
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | marawi
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | rawson
# Processing Record 45 of Set 2 | pacific grove
# Processing Record 46 of Set 2 | beloha
# Processing Record 47 of Set 2 | natal
# Processing Record 48 of Set 2 | luderitz
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | tilichiki
# Processing Record 1 of Set 3 | wagar
# Processing Record 2 of Set 3 | mount isa
# Processing Record 3 of Set 3 | port hedland
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | alofi
# Processing Record 6 of Set 3 | san patricio
# Processing Record 7 of Set 3 | omsukchan
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | vila velha
# Processing Record 10 of Set 3 | half moon bay
# Processing Record 11 of Set 3 | beringovskiy
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | aklavik
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | atuona
# Processing Record 18 of Set 3 | roebourne
# Processing Record 19 of Set 3 | teluk nibung
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | flinders
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | nikolskoye
# Processing Record 26 of Set 3 | provideniya
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | mayumba
# Processing Record 29 of Set 3 | trincomalee
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | orasac
# Processing Record 35 of Set 3 | kangaatsiaq
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 3 | kaligutan
# Processing Record 39 of Set 3 | bende
# Processing Record 40 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | yulara
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | havoysund
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | ekhabi
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | bonfim
# Processing Record 50 of Set 3 | komsomolskiy
# Processing Record 1 of Set 4 | bradford
# Processing Record 2 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | hami
# Processing Record 5 of Set 4 | sao miguel do araguaia
# Processing Record 6 of Set 4 | bouca
# Processing Record 7 of Set 4 | wajima
# Processing Record 8 of Set 4 | guanica
# Processing Record 9 of Set 4 | fortuna
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | axim
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | westport
# Processing Record 14 of Set 4 | mayo
# Processing Record 15 of Set 4 | chapais
# Processing Record 16 of Set 4 | kropotkin
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | palana
# Processing Record 19 of Set 4 | mabaruma
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | viedma
# Processing Record 23 of Set 4 | sinnamary
# Processing Record 24 of Set 4 | kutum
# Processing Record 25 of Set 4 | otane
# Processing Record 26 of Set 4 | kupino
# Processing Record 27 of Set 4 | saint-pierre
# Processing Record 28 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 4 | antonina
# Processing Record 30 of Set 4 | luanda
# Processing Record 31 of Set 4 | gainesville
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | port alfred
# Processing Record 34 of Set 4 | teya
# Processing Record 35 of Set 4 | sovetskiy
# Processing Record 36 of Set 4 | vao
# Processing Record 37 of Set 4 | cherskiy
# Processing Record 38 of Set 4 | derzhavinsk
# Processing Record 39 of Set 4 | gorontalo
# Processing Record 40 of Set 4 | la asuncion
# Processing Record 41 of Set 4 | russell
# Processing Record 42 of Set 4 | catemaco
# Processing Record 43 of Set 4 | alcantara
# Processing Record 44 of Set 4 | hastings
# Processing Record 45 of Set 4 | manta
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | hovd
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | santa elena
# Processing Record 2 of Set 5 | tommot
# Processing Record 3 of Set 5 | srednekolymsk
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | tautira
# Processing Record 6 of Set 5 | college
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | correntina
# Processing Record 9 of Set 5 | sao filipe
# Processing Record 10 of Set 5 | paita
# Processing Record 11 of Set 5 | hwange
# Processing Record 12 of Set 5 | manjeri
# Processing Record 13 of Set 5 | morehead
# Processing Record 14 of Set 5 | sakaiminato
# Processing Record 15 of Set 5 | casablanca
# Processing Record 16 of Set 5 | port lincoln
# Processing Record 17 of Set 5 | uchaly
# Processing Record 18 of Set 5 | tera
# Processing Record 19 of Set 5 | sola
# Processing Record 20 of Set 5 | bonavista
# Processing Record 21 of Set 5 | north platte
# Processing Record 22 of Set 5 | ilhabela
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | vernon
# Processing Record 25 of Set 5 | igarapava
# Processing Record 26 of Set 5 | kasane
# Processing Record 27 of Set 5 | ola
# Processing Record 28 of Set 5 | ulladulla
# Processing Record 29 of Set 5 | athabasca
# Processing Record 30 of Set 5 | paamiut
# Processing Record 31 of Set 5 | karratha
# Processing Record 32 of Set 5 | bandarbeyla
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | juan lacaze
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | helong
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | krasnoselkup
# Processing Record 40 of Set 5 | vallenar
# Processing Record 41 of Set 5 | mehamn
# Processing Record 42 of Set 5 | marsa matruh
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | banjar
# Processing Record 45 of Set 5 | arlit
# Processing Record 46 of Set 5 | chenzhou
# Processing Record 47 of Set 5 | mocuba
# Processing Record 48 of Set 5 | roros
# Processing Record 49 of Set 5 | havre-saint-pierre
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | broome
# Processing Record 2 of Set 6 | iqaluit
# Processing Record 3 of Set 6 | kapurthala
# Processing Record 4 of Set 6 | agadez
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | ilinskiy
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | upernavik
# Processing Record 9 of Set 6 | taoudenni
# Processing Record 10 of Set 6 | mnogovershinnyy
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | los llanos de aridane
# Processing Record 13 of Set 6 | helena
# Processing Record 14 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 6 | virginia beach
# Processing Record 16 of Set 6 | smithers
# Processing Record 17 of Set 6 | evanston
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | bonawon
# Processing Record 20 of Set 6 | dabola
# Processing Record 21 of Set 6 | yeppoon
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | taltal
# Processing Record 24 of Set 6 | amancio
# City not found. Skipping...
# Processing Record 25 of Set 6 | magadi
# Processing Record 26 of Set 6 | lushunkou
# City not found. Skipping...
# Processing Record 27 of Set 6 | qaqortoq
# Processing Record 28 of Set 6 | souillac
# Processing Record 29 of Set 6 | te anau
# Processing Record 30 of Set 6 | sorland
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | paraiso
# Processing Record 33 of Set 6 | tateyama
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | hirara
# Processing Record 37 of Set 6 | chengzihe
# Processing Record 38 of Set 6 | husavik
# Processing Record 39 of Set 6 | bambous virieux
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | lavrentiya
# Processing Record 42 of Set 6 | caratinga
# Processing Record 43 of Set 6 | odienne
# Processing Record 44 of Set 6 | hobyo
# Processing Record 45 of Set 6 | buraydah
# Processing Record 46 of Set 6 | alice springs
# Processing Record 47 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 6 | nemuro
# Processing Record 49 of Set 6 | nabul
# City not found. Skipping...
# Processing Record 50 of Set 6 | diamantino
# Processing Record 1 of Set 7 | puerto escondido
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | paragould
# Processing Record 4 of Set 7 | charters towers
# Processing Record 5 of Set 7 | sabang
# Processing Record 6 of Set 7 | boa vista
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | gomel
# Processing Record 9 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | eureka
# Processing Record 11 of Set 7 | reforma
# Processing Record 12 of Set 7 | tezpur
# Processing Record 13 of Set 7 | shingu
# Processing Record 14 of Set 7 | poopo
# Processing Record 15 of Set 7 | birao
# Processing Record 16 of Set 7 | barahona
# Processing Record 17 of Set 7 | kresttsy
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | pahrump
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | otradnoye
# Processing Record 22 of Set 7 | haverfordwest
# Processing Record 23 of Set 7 | tambovka
# Processing Record 24 of Set 7 | ulaanbaatar
# Processing Record 25 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 7 | anacortes
# Processing Record 27 of Set 7 | ca mau
# Processing Record 28 of Set 7 | kalabo
# Processing Record 29 of Set 7 | nome
# Processing Record 30 of Set 7 | riyadh
# Processing Record 31 of Set 7 | tadine
# Processing Record 32 of Set 7 | deyang
# Processing Record 33 of Set 7 | kemijarvi
# Processing Record 34 of Set 7 | northam
# Processing Record 35 of Set 7 | itarema
# Processing Record 36 of Set 7 | pobe
# Processing Record 37 of Set 7 | itaituba
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | santa cruz
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | kimbe
# Processing Record 43 of Set 7 | vestmannaeyjar
# Processing Record 44 of Set 7 | khasan
# Processing Record 45 of Set 7 | pevek
# Processing Record 46 of Set 7 | ischia
# Processing Record 47 of Set 7 | ukiah
# Processing Record 48 of Set 7 | klaksvik
# Processing Record 49 of Set 7 | odweyne
# Processing Record 50 of Set 7 | camalu
# Processing Record 1 of Set 8 | megion
# Processing Record 2 of Set 8 | grindavik
# Processing Record 3 of Set 8 | wanaka
# Processing Record 4 of Set 8 | menongue
# Processing Record 5 of Set 8 | nurota
# Processing Record 6 of Set 8 | horqueta
# Processing Record 7 of Set 8 | horsham
# Processing Record 8 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | port macquarie
# Processing Record 11 of Set 8 | mae sai
# Processing Record 12 of Set 8 | honningsvag
# Processing Record 13 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | guerrero negro
# Processing Record 16 of Set 8 | nkhotakota
# Processing Record 17 of Set 8 | lima
# Processing Record 18 of Set 8 | surskoye
# Processing Record 19 of Set 8 | kurumkan
# Processing Record 20 of Set 8 | dalvik
# Processing Record 21 of Set 8 | faanui
# Processing Record 22 of Set 8 | waddan
# Processing Record 23 of Set 8 | meulaboh
# Processing Record 24 of Set 8 | khani
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | iwanai
# Processing Record 27 of Set 8 | conceicao do araguaia
# Processing Record 28 of Set 8 | hvolsvollur
# Processing Record 29 of Set 8 | baykit
# Processing Record 30 of Set 8 | gaildorf
# Processing Record 31 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 8 | lucapa
# Processing Record 33 of Set 8 | cururupu
# Processing Record 34 of Set 8 | carmen
# Processing Record 35 of Set 8 | bourail
# Processing Record 36 of Set 8 | along
# Processing Record 37 of Set 8 | kiruna
# Processing Record 38 of Set 8 | repnoye
# Processing Record 39 of Set 8 | san vicente
# Processing Record 40 of Set 8 | markova
# Processing Record 41 of Set 8 | abonnema
# Processing Record 42 of Set 8 | yenagoa
# Processing Record 43 of Set 8 | boende
# Processing Record 44 of Set 8 | rock sound
# Processing Record 45 of Set 8 | kandrian
# Processing Record 46 of Set 8 | moose factory
# Processing Record 47 of Set 8 | dobson
# Processing Record 48 of Set 8 | maltahohe
# Processing Record 49 of Set 8 | ardabil
# Processing Record 50 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 9 | harindanga
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 9 | cabedelo
# Processing Record 6 of Set 9 | akureyri
# Processing Record 7 of Set 9 | houma
# Processing Record 8 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 9 | nokia
# Processing Record 10 of Set 9 | richard toll
# City not found. Skipping...
# Processing Record 11 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 9 | gawler
# Processing Record 13 of Set 9 | port moresby
# Processing Record 14 of Set 9 | codrington
# Processing Record 15 of Set 9 | am timan
# Processing Record 16 of Set 9 | quepos
# Processing Record 17 of Set 9 | aguimes
# Processing Record 18 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 9 | peleduy
# Processing Record 20 of Set 9 | nieves
# Processing Record 21 of Set 9 | magadan
# Processing Record 22 of Set 9 | asau
# Processing Record 23 of Set 9 | margate
# Processing Record 24 of Set 9 | huarmey
# Processing Record 25 of Set 9 | campos altos
# Processing Record 26 of Set 9 | manado
# Processing Record 27 of Set 9 | cairns
# Processing Record 28 of Set 9 | awjilah
# Processing Record 29 of Set 9 | mahibadhoo
# Processing Record 30 of Set 9 | saint-louis
# Processing Record 31 of Set 9 | gubkinskiy
# Processing Record 32 of Set 9 | urambo
# Processing Record 33 of Set 9 | bure
# Processing Record 34 of Set 9 | jobat
# Processing Record 35 of Set 9 | tibati
# Processing Record 36 of Set 9 | kamenka
# Processing Record 37 of Set 9 | saint-georges
# Processing Record 38 of Set 9 | grand baie
# Processing Record 39 of Set 9 | gat
# Processing Record 40 of Set 9 | katobu
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | jesus de otoro
# Processing Record 43 of Set 9 | tarauaca
# Processing Record 44 of Set 9 | pilar
# Processing Record 45 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 47 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 9 | troitskoye
# Processing Record 49 of Set 9 | thinadhoo
# Processing Record 50 of Set 9 | tukrah
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | sladkovo
# Processing Record 3 of Set 10 | duartina
# Processing Record 4 of Set 10 | nogliki
# Processing Record 5 of Set 10 | marzuq
# Processing Record 6 of Set 10 | mmabatho
# Processing Record 7 of Set 10 | springfield
# Processing Record 8 of Set 10 | omboue
# Processing Record 9 of Set 10 | vardo
# Processing Record 10 of Set 10 | zeya
# Processing Record 11 of Set 10 | nara
# Processing Record 12 of Set 10 | coolum beach
# Processing Record 13 of Set 10 | chulym
# Processing Record 14 of Set 10 | miltenberg
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | flin flon
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | samarai
# Processing Record 19 of Set 10 | wattegama
# Processing Record 20 of Set 10 | quatre cocos
# Processing Record 21 of Set 10 | villa bruzual
# Processing Record 22 of Set 10 | inuvik
# Processing Record 23 of Set 10 | altamont
# Processing Record 24 of Set 10 | sinegorye
# Processing Record 25 of Set 10 | cockburn town
# Processing Record 26 of Set 10 | narsaq
# Processing Record 27 of Set 10 | zhangjiakou
# Processing Record 28 of Set 10 | nanakuli
# Processing Record 29 of Set 10 | puro
# Processing Record 30 of Set 10 | mareeba
# Processing Record 31 of Set 10 | agropoli
# Processing Record 32 of Set 10 | ridgetown
# Processing Record 33 of Set 10 | sri aman
# Processing Record 34 of Set 10 | zhigansk
# Processing Record 35 of Set 10 | zwedru
# Processing Record 36 of Set 10 | saint-francois
# Processing Record 37 of Set 10 | tuzha
# Processing Record 38 of Set 10 | kailua
# Processing Record 39 of Set 10 | rio gallegos
# Processing Record 40 of Set 10 | tura
# Processing Record 41 of Set 10 | dingle
# Processing Record 42 of Set 10 | ayan
# Processing Record 43 of Set 10 | muzhi
# Processing Record 44 of Set 10 | alto araguaia
# Processing Record 45 of Set 10 | benalla
# Processing Record 46 of Set 10 | lauria
# Processing Record 47 of Set 10 | nawabganj
# Processing Record 48 of Set 10 | tabuk
# Processing Record 49 of Set 10 | rosarito
# Processing Record 50 of Set 10 | eyl
# Processing Record 1 of Set 11 | qostanay
# Processing Record 2 of Set 11 | hit
# Processing Record 3 of Set 11 | haines junction
# Processing Record 4 of Set 11 | mayya
# Processing Record 5 of Set 11 | monrovia
# Processing Record 6 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 7 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 8 of Set 11 | arona
# Processing Record 9 of Set 11 | durango
# Processing Record 10 of Set 11 | presidencia roque saenz pena
# Processing Record 11 of Set 11 | namibe
# Processing Record 12 of Set 11 | sandy bay
# Processing Record 13 of Set 11 | paoua
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | yuanping
# Processing Record 16 of Set 11 | borogontsy
# Processing Record 17 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | bagdarin
# Processing Record 19 of Set 11 | aden
# Processing Record 20 of Set 11 | sept-iles
# Processing Record 21 of Set 11 | oistins
# Processing Record 22 of Set 11 | othonoi
# City not found. Skipping...
# Processing Record 23 of Set 11 | safford
# Processing Record 24 of Set 11 | oranjestad
# Processing Record 25 of Set 11 | kavaratti
# Processing Record 26 of Set 11 | kurchum
# Processing Record 27 of Set 11 | batsfjord
# Processing Record 28 of Set 11 | elesbao veloso
# Processing Record 29 of Set 11 | weihe
# Processing Record 30 of Set 11 | pangkalanbuun
# Processing Record 31 of Set 11 | tela
# Processing Record 32 of Set 11 | tongchuan
# Processing Record 33 of Set 11 | ordynskoye
# Processing Record 34 of Set 11 | esna
# Processing Record 35 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 11 | yashkino
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | yichun
# Processing Record 39 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 11 | bukachacha
# Processing Record 41 of Set 11 | marietta
# Processing Record 42 of Set 11 | irbil
# Processing Record 43 of Set 11 | voyvozh
# Processing Record 44 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | xai-xai
# Processing Record 46 of Set 11 | benjamin constant
# Processing Record 47 of Set 11 | puerto cabezas
# Processing Record 48 of Set 11 | calabozo
# Processing Record 49 of Set 11 | yazd
# Processing Record 50 of Set 11 | inhambane
# Processing Record 1 of Set 12 | altamirano
# Processing Record 2 of Set 12 | obuasi
# Processing Record 3 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 12 | louis trichardt
# Processing Record 6 of Set 12 | kungurtug
# Processing Record 7 of Set 12 | xinxiang
# Processing Record 8 of Set 12 | guadalupe y calvo
# Processing Record 9 of Set 12 | manokwari
# Processing Record 10 of Set 12 | krasnovishersk
# Processing Record 11 of Set 12 | oum hadjer
# Processing Record 12 of Set 12 | tomaszow mazowiecki
# Processing Record 13 of Set 12 | ponte nova
# Processing Record 14 of Set 12 | nantucket
# Processing Record 15 of Set 12 | ambon
# Processing Record 16 of Set 12 | galesong
# Processing Record 17 of Set 12 | kodinsk
# Processing Record 18 of Set 12 | kapit
# Processing Record 19 of Set 12 | skjervoy
# Processing Record 20 of Set 12 | berdigestyakh
# Processing Record 21 of Set 12 | winchester
# Processing Record 22 of Set 12 | novikovo
# Processing Record 23 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 24 of Set 12 | javanrud
# Processing Record 25 of Set 12 | san carlos de bariloche
# Processing Record 26 of Set 12 | tres arroyos
# Processing Record 27 of Set 12 | bogo
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | mazagao
# Processing Record 30 of Set 12 | santa isabel do rio negro
# Processing Record 31 of Set 12 | nerchinskiy zavod
# Processing Record 32 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 12 | sao lourenco do oeste
# Processing Record 35 of Set 12 | valparaiso
# Processing Record 36 of Set 12 | arica
# Processing Record 37 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | koungheul
# Processing Record 40 of Set 12 | canutama
# Processing Record 41 of Set 12 | nova olimpia
# Processing Record 42 of Set 12 | kassala
# Processing Record 43 of Set 12 | bam
# Processing Record 44 of Set 12 | najran
# Processing Record 45 of Set 12 | sur
# Processing Record 46 of Set 12 | zheleznodorozhnyy
# Processing Record 47 of Set 12 | ornskoldsvik
# Processing Record 48 of Set 12 | empalme
# Processing Record 49 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 12 | annau
# Processing Record 1 of Set 13 | tenenkou
# Processing Record 2 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 13 | talisay
# Processing Record 4 of Set 13 | mitu
# Processing Record 5 of Set 13 | chikhli
# Processing Record 6 of Set 13 | muyezerskiy
# Processing Record 7 of Set 13 | xinmin
# Processing Record 8 of Set 13 | khalkhal
# Processing Record 9 of Set 13 | pokhara
# Processing Record 10 of Set 13 | marau
# Processing Record 11 of Set 13 | vestmanna
# Processing Record 12 of Set 13 | santiago del estero
# Processing Record 13 of Set 13 | xuddur
# Processing Record 14 of Set 13 | gweru
# Processing Record 15 of Set 13 | yamada
# Processing Record 16 of Set 13 | esmeraldas
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | nueva loja
# Processing Record 19 of Set 13 | sidi ali
# Processing Record 20 of Set 13 | soma
# Processing Record 21 of Set 13 | biltine
# Processing Record 22 of Set 13 | biak
# Processing Record 23 of Set 13 | galle
# Processing Record 24 of Set 13 | sagua la grande
# Processing Record 25 of Set 13 | filimonovo
# Processing Record 26 of Set 13 | katwa
# Processing Record 27 of Set 13 | murray bridge
# Processing Record 28 of Set 13 | aykhal
# Processing Record 29 of Set 13 | shihezi
# Processing Record 30 of Set 13 | nabire
# Processing Record 31 of Set 13 | serpukhov
# Processing Record 32 of Set 13 | sao felix do xingu
# Processing Record 33 of Set 13 | novotroitskaya
# Processing Record 34 of Set 13 | mahon
# Processing Record 35 of Set 13 | tineo
# Processing Record 36 of Set 13 | lagoa
# Processing Record 37 of Set 13 | avera
# Processing Record 38 of Set 13 | praia
# Processing Record 39 of Set 13 | ponta pora
# Processing Record 40 of Set 13 | quirinopolis
# Processing Record 41 of Set 13 | pierre
# Processing Record 42 of Set 13 | san juan de los morros
# Processing Record 43 of Set 13 | krionerion
# City not found. Skipping...
# Processing Record 44 of Set 13 | baoning
# Processing Record 45 of Set 13 | abha
# Processing Record 46 of Set 13 | wenchi
# Processing Record 47 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 13 | bafq
# Processing Record 49 of Set 13 | jales
# Processing Record 50 of Set 13 | ust-ilimsk
# Processing Record 1 of Set 14 | lakes entrance
# Processing Record 2 of Set 14 | henderson
# Processing Record 3 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 14 | dharchula
# Processing Record 5 of Set 14 | hisor
# Processing Record 6 of Set 14 | altay
# Processing Record 7 of Set 14 | khandbari
# Processing Record 8 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 14 | rincon
# Processing Record 10 of Set 14 | brae
# Processing Record 11 of Set 14 | domoni
# Processing Record 12 of Set 14 | bud
# Processing Record 13 of Set 14 | kita
# Processing Record 14 of Set 14 | hofn
# Processing Record 15 of Set 14 | el alto
# Processing Record 16 of Set 14 | qaracala
# Processing Record 17 of Set 14 | kirakira
# Processing Record 18 of Set 14 | poso
# Processing Record 19 of Set 14 | madawaska
# Processing Record 20 of Set 14 | sainte-anne-des-monts
# Processing Record 21 of Set 14 | stolin
# Processing Record 22 of Set 14 | labuan
# Processing Record 23 of Set 14 | aguadilla
# Processing Record 24 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 14 | tamiahua
# Processing Record 26 of Set 14 | saint combs
# City not found. Skipping...
# Processing Record 27 of Set 14 | lazaro cardenas
# Processing Record 28 of Set 14 | fujin
# Processing Record 29 of Set 14 | kulhudhuffushi
# Processing Record 30 of Set 14 | sandakan
# Processing Record 31 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 32 of Set 14 | langsa
# Processing Record 33 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 34 of Set 14 | hervey bay
# Processing Record 35 of Set 14 | sungaipenuh
# Processing Record 36 of Set 14 | diego de almagro
# Processing Record 37 of Set 14 | ascension
# Processing Record 38 of Set 14 | linqiong
# Processing Record 39 of Set 14 | fort-shevchenko
# Processing Record 40 of Set 14 | vanersborg
# Processing Record 41 of Set 14 | aswan
# Processing Record 42 of Set 14 | surami
# Processing Record 43 of Set 14 | tyukhtet
# Processing Record 44 of Set 14 | samalkot
# Processing Record 45 of Set 14 | mogadishu
# Processing Record 46 of Set 14 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 14 | kalat
# Processing Record 48 of Set 14 | rovaniemi
# Processing Record 49 of Set 14 | moron
# Processing Record 50 of Set 14 | kostomuksha
# Processing Record 1 of Set 15 | tanuku
# Processing Record 2 of Set 15 | hengshui
# Processing Record 3 of Set 15 | chicama
# Processing Record 4 of Set 15 | laguna
# Processing Record 5 of Set 15 | araouane
# Processing Record 6 of Set 15 | villablino
# Processing Record 7 of Set 15 | trelew
# Processing Record 8 of Set 15 | sao geraldo do araguaia
# Processing Record 9 of Set 15 | rio tercero
# Processing Record 10 of Set 15 | morecambe
# Processing Record 11 of Set 15 | cap malheureux
# Processing Record 12 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 15 | twentynine palms
# Processing Record 14 of Set 15 | cap-aux-meules
# Processing Record 15 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 15 | barquisimeto
# Processing Record 17 of Set 15 | japura
# Processing Record 18 of Set 15 | concepcion
# Processing Record 19 of Set 15 | maniitsoq
# Processing Record 20 of Set 15 | senador pompeu
# Processing Record 21 of Set 15 | uruzgan
# Processing Record 22 of Set 15 | melo
# Processing Record 23 of Set 15 | kontagora
# Processing Record 24 of Set 15 | pereslavl-zalesskiy
# Processing Record 25 of Set 15 | iquitos
# Processing Record 26 of Set 15 | maketu
# Processing Record 27 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 15 | yining
# Processing Record 29 of Set 15 | trairi
# Processing Record 30 of Set 15 | morris
# Processing Record 31 of Set 15 | kruisfontein
# Processing Record 32 of Set 15 | valdosta
# Processing Record 33 of Set 15 | dandong
# Processing Record 34 of Set 15 | bhakkar
# Processing Record 35 of Set 15 | lata
# Processing Record 36 of Set 15 | verkhnevilyuysk
# Processing Record 37 of Set 15 | boundiali
# Processing Record 38 of Set 15 | cayenne
# Processing Record 39 of Set 15 | tezu
# Processing Record 40 of Set 15 | bilma
# Processing Record 41 of Set 15 | mpraeso
# Processing Record 42 of Set 15 | bosaso
# Processing Record 43 of Set 15 | tiarei
# Processing Record 44 of Set 15 | labytnangi
# Processing Record 45 of Set 15 | padang
# Processing Record 46 of Set 15 | matamoros
# Processing Record 47 of Set 15 | santa cruz del sur
# Processing Record 48 of Set 15 | khorixas
# Processing Record 49 of Set 15 | flagstaff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Clarence Town      AU -32.5833  151.7833     69.35        48           0
# 1        Ushuaia      AR -54.8000  -68.3000     33.46        86          20
# 2     Chokurdakh      RU  70.6333  147.9167     56.43        40          56
# 3       Maragogi      BR  -9.0122  -35.2225     72.79        88          28
# 4        Qaanaaq      GL  77.4840  -69.3632     36.86        74         100
# 5      Itamaraca      BR  -7.7478  -34.8256     72.28        86          60
# 6     Champerico      GT  14.3000  -91.9167     81.77        76          92
# 7           Okha      RU  53.5739  142.9478     76.69        68         100
# 8         Konevo      RU  62.1215   39.3192     62.15        67          92
# 9           Naze      JP  28.3667  129.4833     83.32        93         100
#
#    Wind Speed Current Description
# 0       12.15           clear sky
# 1       14.97          few clouds
# 2        9.98       broken clouds
# 3       10.07    scattered clouds
# 4        2.82     overcast clouds
# 5       11.92       broken clouds
# 6        4.32     overcast clouds
# 7        9.57     overcast clouds
# 8        7.23     overcast clouds
# 9       17.38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
