# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lng = zip(lat, lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bambous virieux
# Processing Record 2 of Set 1 | yako
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | muroto
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | biltine
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | messina
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | grindavik
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | pacific grove
# Processing Record 22 of Set 1 | ballina
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | vitim
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | omboue
# Processing Record 27 of Set 1 | hami
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | malinovskiy
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | vuktyl
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | freetown
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | teguise
# Processing Record 42 of Set 1 | te anau
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | bronderslev
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | morant bay
# Processing Record 49 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | ravar
# Processing Record 4 of Set 2 | agua branca
# Processing Record 5 of Set 2 | basar
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | acajutla
# Processing Record 8 of Set 2 | luganville
# Processing Record 9 of Set 2 | bubaque
# Processing Record 10 of Set 2 | geraldton
# Processing Record 11 of Set 2 | akdepe
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | los andes
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | samaipata
# Processing Record 17 of Set 2 | kitimat
# Processing Record 18 of Set 2 | bima
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | severo-kurilsk
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | ketchikan
# Processing Record 25 of Set 2 | taree
# Processing Record 26 of Set 2 | laguna
# Processing Record 27 of Set 2 | coruripe
# Processing Record 28 of Set 2 | palana
# Processing Record 29 of Set 2 | erenhot
# Processing Record 30 of Set 2 | port-cartier
# Processing Record 31 of Set 2 | yerbogachen
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | olhao
# Processing Record 35 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 2 | druskininkai
# Processing Record 37 of Set 2 | homer
# Processing Record 38 of Set 2 | pisco
# Processing Record 39 of Set 2 | srednekolymsk
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | borogontsy
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | port-gentil
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | moba
# Processing Record 47 of Set 2 | almaznyy
# Processing Record 48 of Set 2 | la palma
# Processing Record 49 of Set 2 | dunedin
# Processing Record 50 of Set 2 | zadonsk
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | alcazar de san juan
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | chicama
# Processing Record 7 of Set 3 | baiyin
# Processing Record 8 of Set 3 | salalah
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | sisimiut
# Processing Record 12 of Set 3 | shizunai
# Processing Record 13 of Set 3 | inuvik
# Processing Record 14 of Set 3 | coquimbo
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | paducah
# Processing Record 17 of Set 3 | acarau
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | kavaratti
# Processing Record 20 of Set 3 | mazyr
# Processing Record 21 of Set 3 | abonnema
# Processing Record 22 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 3 | banda aceh
# Processing Record 24 of Set 3 | port lavaca
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | saldanha
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | buriti dos lopes
# Processing Record 31 of Set 3 | panjakent
# Processing Record 32 of Set 3 | moose factory
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | huangmei
# Processing Record 38 of Set 3 | neiafu
# Processing Record 39 of Set 3 | imbituba
# Processing Record 40 of Set 3 | svetlogorsk
# Processing Record 41 of Set 3 | palmas
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | adre
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | mbandaka
# Processing Record 46 of Set 3 | north bend
# Processing Record 47 of Set 3 | iracoubo
# Processing Record 48 of Set 3 | olinda
# Processing Record 49 of Set 3 | walvis bay
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | henties bay
# Processing Record 2 of Set 4 | dawei
# Processing Record 3 of Set 4 | kudahuvadhoo
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | le port
# Processing Record 6 of Set 4 | havre-saint-pierre
# Processing Record 7 of Set 4 | chapais
# Processing Record 8 of Set 4 | saskylakh
# Processing Record 9 of Set 4 | lagoa
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | mouila
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | port macquarie
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | abha
# Processing Record 17 of Set 4 | hermanus
# Processing Record 18 of Set 4 | karratha
# Processing Record 19 of Set 4 | la solana
# Processing Record 20 of Set 4 | richards bay
# Processing Record 21 of Set 4 | abapo
# Processing Record 22 of Set 4 | belorechensk
# Processing Record 23 of Set 4 | leningradskiy
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | palm valley
# Processing Record 27 of Set 4 | tromso
# Processing Record 28 of Set 4 | morgan city
# Processing Record 29 of Set 4 | saint-denis
# Processing Record 30 of Set 4 | umm lajj
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | ancud
# Processing Record 33 of Set 4 | manokwari
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | sri aman
# Processing Record 37 of Set 4 | sept-iles
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | victoria
# Processing Record 40 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 4 | puerto penasco
# Processing Record 42 of Set 4 | lesosibirsk
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | los llanos de aridane
# Processing Record 46 of Set 4 | dodola
# Processing Record 47 of Set 4 | college
# Processing Record 48 of Set 4 | seymchan
# Processing Record 49 of Set 4 | kendallville
# Processing Record 50 of Set 4 | port lincoln
# Processing Record 1 of Set 5 | samana
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | muros
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | brigantine
# Processing Record 7 of Set 5 | guane
# Processing Record 8 of Set 5 | sal rei
# Processing Record 9 of Set 5 | lianzhou
# Processing Record 10 of Set 5 | dubti
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | san patricio
# Processing Record 13 of Set 5 | romanovo
# Processing Record 14 of Set 5 | mbinga
# Processing Record 15 of Set 5 | puerto palomas
# Processing Record 16 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | kidal
# Processing Record 19 of Set 5 | san cristobal
# Processing Record 20 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | kilindoni
# Processing Record 22 of Set 5 | tilichiki
# Processing Record 23 of Set 5 | eldama ravine
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | lebu
# Processing Record 26 of Set 5 | sitka
# Processing Record 27 of Set 5 | kinsale
# Processing Record 28 of Set 5 | yeppoon
# Processing Record 29 of Set 5 | vanavara
# Processing Record 30 of Set 5 | aviles
# Processing Record 31 of Set 5 | carauari
# Processing Record 32 of Set 5 | tiznit
# Processing Record 33 of Set 5 | touros
# Processing Record 34 of Set 5 | lata
# Processing Record 35 of Set 5 | ust-ishim
# Processing Record 36 of Set 5 | morondava
# Processing Record 37 of Set 5 | sao jose da coroa grande
# Processing Record 38 of Set 5 | mujiayingzi
# Processing Record 39 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 5 | aripuana
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | mar del plata
# Processing Record 43 of Set 5 | miyang
# Processing Record 44 of Set 5 | mikun
# Processing Record 45 of Set 5 | dengfeng
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | iglesias
# Processing Record 49 of Set 5 | isangel
# Processing Record 50 of Set 5 | vao
# Processing Record 1 of Set 6 | hendijan
# City not found. Skipping...
# Processing Record 2 of Set 6 | jumla
# Processing Record 3 of Set 6 | jhang
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | caceres
# Processing Record 6 of Set 6 | fare
# Processing Record 7 of Set 6 | oros
# Processing Record 8 of Set 6 | port hardy
# Processing Record 9 of Set 6 | ambon
# Processing Record 10 of Set 6 | gobabis
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | canillo
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 6 | kulhudhuffushi
# Processing Record 16 of Set 6 | cairns
# Processing Record 17 of Set 6 | thompson
# Processing Record 18 of Set 6 | dunmore town
# Processing Record 19 of Set 6 | kozhva
# Processing Record 20 of Set 6 | hovd
# Processing Record 21 of Set 6 | longyearbyen
# Processing Record 22 of Set 6 | wanning
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | manzhouli
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | talcahuano
# Processing Record 27 of Set 6 | thai binh
# Processing Record 28 of Set 6 | nuuk
# Processing Record 29 of Set 6 | tonantins
# Processing Record 30 of Set 6 | moerai
# Processing Record 31 of Set 6 | makakilo city
# Processing Record 32 of Set 6 | zeya
# Processing Record 33 of Set 6 | kavieng
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | flin flon
# Processing Record 36 of Set 6 | skjervoy
# Processing Record 37 of Set 6 | seminole
# Processing Record 38 of Set 6 | ambatolampy
# Processing Record 39 of Set 6 | jakovo
# Processing Record 40 of Set 6 | teguldet
# Processing Record 41 of Set 6 | cabedelo
# Processing Record 42 of Set 6 | banamba
# Processing Record 43 of Set 6 | bom jesus
# Processing Record 44 of Set 6 | high level
# Processing Record 45 of Set 6 | mpanda
# Processing Record 46 of Set 6 | iberia
# Processing Record 47 of Set 6 | wohlen
# Processing Record 48 of Set 6 | hobyo
# Processing Record 49 of Set 6 | provideniya
# Processing Record 50 of Set 6 | san rafael
# Processing Record 1 of Set 7 | mazamari
# Processing Record 2 of Set 7 | cascais
# Processing Record 3 of Set 7 | mayna
# Processing Record 4 of Set 7 | tyukhtet
# Processing Record 5 of Set 7 | luderitz
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | betlitsa
# Processing Record 9 of Set 7 | saratoga springs
# Processing Record 10 of Set 7 | sorong
# Processing Record 11 of Set 7 | ilulissat
# Processing Record 12 of Set 7 | southbridge
# Processing Record 13 of Set 7 | atyrau
# Processing Record 14 of Set 7 | cheney
# Processing Record 15 of Set 7 | zarate
# Processing Record 16 of Set 7 | fethiye
# Processing Record 17 of Set 7 | onega
# Processing Record 18 of Set 7 | klaksvik
# Processing Record 19 of Set 7 | tual
# Processing Record 20 of Set 7 | mitu
# Processing Record 21 of Set 7 | tiksi
# Processing Record 22 of Set 7 | aketi
# Processing Record 23 of Set 7 | atar
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | cabinda
# Processing Record 26 of Set 7 | xacmaz
# Processing Record 27 of Set 7 | nenjiang
# Processing Record 28 of Set 7 | komsomolskiy
# Processing Record 29 of Set 7 | riyadh
# Processing Record 30 of Set 7 | partapur
# Processing Record 31 of Set 7 | veinticinco de mayo
# Processing Record 32 of Set 7 | udachnyy
# Processing Record 33 of Set 7 | kochi
# Processing Record 34 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 7 | suixi
# Processing Record 36 of Set 7 | katima mulilo
# Processing Record 37 of Set 7 | lira
# Processing Record 38 of Set 7 | luanda
# Processing Record 39 of Set 7 | fuyang
# Processing Record 40 of Set 7 | batasan
# Processing Record 41 of Set 7 | yelbarga
# Processing Record 42 of Set 7 | pedro ii
# Processing Record 43 of Set 7 | bethel
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | da nang
# Processing Record 46 of Set 7 | berlevag
# Processing Record 47 of Set 7 | kruisfontein
# Processing Record 48 of Set 7 | nhlangano
# Processing Record 49 of Set 7 | sabang
# Processing Record 50 of Set 7 | pytalovo
# Processing Record 1 of Set 8 | yizheng
# Processing Record 2 of Set 8 | la romana
# Processing Record 3 of Set 8 | saint-pierre
# Processing Record 4 of Set 8 | mehamn
# Processing Record 5 of Set 8 | toledo
# Processing Record 6 of Set 8 | florence
# Processing Record 7 of Set 8 | tuatapere
# Processing Record 8 of Set 8 | husavik
# Processing Record 9 of Set 8 | huangcun
# Processing Record 10 of Set 8 | tafalla
# Processing Record 11 of Set 8 | porto novo
# Processing Record 12 of Set 8 | bud
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | kemin
# Processing Record 15 of Set 8 | cubuk
# Processing Record 16 of Set 8 | ust-koksa
# Processing Record 17 of Set 8 | mnogovershinnyy
# Processing Record 18 of Set 8 | otawara
# Processing Record 19 of Set 8 | huarmey
# Processing Record 20 of Set 8 | havoysund
# Processing Record 21 of Set 8 | kokopo
# Processing Record 22 of Set 8 | labranzagrande
# Processing Record 23 of Set 8 | california city
# Processing Record 24 of Set 8 | cristobal obregon
# Processing Record 25 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 8 | turukhansk
# Processing Record 27 of Set 8 | puerto madryn
# Processing Record 28 of Set 8 | el bagre
# Processing Record 29 of Set 8 | aksarka
# Processing Record 30 of Set 8 | zhangjiakou
# Processing Record 31 of Set 8 | araxa
# Processing Record 32 of Set 8 | canazas
# Processing Record 33 of Set 8 | jiwani
# Processing Record 34 of Set 8 | ayan
# Processing Record 35 of Set 8 | rio gallegos
# Processing Record 36 of Set 8 | tuy hoa
# Processing Record 37 of Set 8 | mamakan
# Processing Record 38 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 8 | svobodnyy
# Processing Record 40 of Set 8 | kutahya
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | wolmaranstad
# City not found. Skipping...
# Processing Record 43 of Set 8 | greystones
# Processing Record 44 of Set 8 | swan hill
# Processing Record 45 of Set 8 | ouro preto do oeste
# Processing Record 46 of Set 8 | belmonte
# Processing Record 47 of Set 8 | norman wells
# Processing Record 48 of Set 8 | atascadero
# Processing Record 49 of Set 8 | pervomayskoye
# Processing Record 50 of Set 8 | christchurch
# Processing Record 1 of Set 9 | gazanjyk
# Processing Record 2 of Set 9 | warrnambool
# Processing Record 3 of Set 9 | yar-sale
# Processing Record 4 of Set 9 | buraydah
# Processing Record 5 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 9 | kendari
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | hokitika
# Processing Record 9 of Set 9 | phrae
# Processing Record 10 of Set 9 | nadym
# Processing Record 11 of Set 9 | fukue
# Processing Record 12 of Set 9 | jishou
# Processing Record 13 of Set 9 | maha sarakham
# Processing Record 14 of Set 9 | adrar
# Processing Record 15 of Set 9 | nabire
# Processing Record 16 of Set 9 | gracac
# Processing Record 17 of Set 9 | tabuk
# Processing Record 18 of Set 9 | waitati
# Processing Record 19 of Set 9 | terme
# Processing Record 20 of Set 9 | narsaq
# Processing Record 21 of Set 9 | nayoro
# Processing Record 22 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 9 | beloha
# Processing Record 24 of Set 9 | xichang
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | rincon
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | loudeac
# Processing Record 29 of Set 9 | tuktoyaktuk
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | nemuro
# Processing Record 32 of Set 9 | misheronskiy
# Processing Record 33 of Set 9 | ullapool
# Processing Record 34 of Set 9 | buala
# Processing Record 35 of Set 9 | disraeli
# Processing Record 36 of Set 9 | krasnyy klyuch
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | saint anthony
# Processing Record 39 of Set 9 | arosa
# Processing Record 40 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 9 | fort nelson
# Processing Record 42 of Set 9 | crotone
# Processing Record 43 of Set 9 | portales
# Processing Record 44 of Set 9 | honiara
# Processing Record 45 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 9 | saint-augustin
# Processing Record 47 of Set 9 | jaisinghnagar
# Processing Record 48 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 9 | maun
# Processing Record 50 of Set 9 | bitung
# Processing Record 1 of Set 10 | aromashevo
# Processing Record 2 of Set 10 | svetlyy
# Processing Record 3 of Set 10 | japura
# Processing Record 4 of Set 10 | shirvan
# Processing Record 5 of Set 10 | margate
# Processing Record 6 of Set 10 | segezha
# Processing Record 7 of Set 10 | necochea
# Processing Record 8 of Set 10 | half moon bay
# Processing Record 9 of Set 10 | chute-aux-outardes
# Processing Record 10 of Set 10 | belaya gora
# Processing Record 11 of Set 10 | saint-joseph
# Processing Record 12 of Set 10 | ratnagiri
# Processing Record 13 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 10 | vila franca do campo
# Processing Record 15 of Set 10 | maltahohe
# Processing Record 16 of Set 10 | biak
# Processing Record 17 of Set 10 | alice springs
# Processing Record 18 of Set 10 | amahai
# Processing Record 19 of Set 10 | whitehorse
# Processing Record 20 of Set 10 | olafsvik
# Processing Record 21 of Set 10 | ljungby
# Processing Record 22 of Set 10 | asau
# Processing Record 23 of Set 10 | palauig
# Processing Record 24 of Set 10 | sao miguel do araguaia
# Processing Record 25 of Set 10 | mersin
# Processing Record 26 of Set 10 | portland
# Processing Record 27 of Set 10 | pilar
# Processing Record 28 of Set 10 | manta
# Processing Record 29 of Set 10 | anchorage
# Processing Record 30 of Set 10 | kaitong
# Processing Record 31 of Set 10 | bereda
# Processing Record 32 of Set 10 | umba
# Processing Record 33 of Set 10 | yulara
# Processing Record 34 of Set 10 | sarangani
# Processing Record 35 of Set 10 | severodvinsk
# Processing Record 36 of Set 10 | anadyr
# Processing Record 37 of Set 10 | trofors
# Processing Record 38 of Set 10 | port keats
# Processing Record 39 of Set 10 | jinka
# Processing Record 40 of Set 10 | guayaramerin
# Processing Record 41 of Set 10 | kiunga
# Processing Record 42 of Set 10 | cockburn town
# Processing Record 43 of Set 10 | mayo
# Processing Record 44 of Set 10 | sabratah
# Processing Record 45 of Set 10 | eureka
# Processing Record 46 of Set 10 | pocatello
# Processing Record 47 of Set 10 | faya
# Processing Record 48 of Set 10 | skibbereen
# Processing Record 49 of Set 10 | hualmay
# Processing Record 50 of Set 10 | pamekasan
# Processing Record 1 of Set 11 | raudeberg
# Processing Record 2 of Set 11 | buhe
# Processing Record 3 of Set 11 | fomboni
# Processing Record 4 of Set 11 | nijar
# Processing Record 5 of Set 11 | port blair
# Processing Record 6 of Set 11 | moiyabana
# City not found. Skipping...
# Processing Record 7 of Set 11 | campoverde
# Processing Record 8 of Set 11 | cochrane
# Processing Record 9 of Set 11 | yugorsk
# Processing Record 10 of Set 11 | hofn
# Processing Record 11 of Set 11 | keti bandar
# Processing Record 12 of Set 11 | bintulu
# Processing Record 13 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 14 of Set 11 | kahului
# Processing Record 15 of Set 11 | gueugnon
# Processing Record 16 of Set 11 | namatanai
# Processing Record 17 of Set 11 | gao
# Processing Record 18 of Set 11 | san jose
# Processing Record 19 of Set 11 | richmond
# Processing Record 20 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 11 | allapalli
# Processing Record 22 of Set 11 | petawawa
# Processing Record 23 of Set 11 | ifanadiana
# Processing Record 24 of Set 11 | macklin
# Processing Record 25 of Set 11 | kuzhener
# Processing Record 26 of Set 11 | teodoro sampaio
# Processing Record 27 of Set 11 | puerto carreno
# Processing Record 28 of Set 11 | tessalit
# Processing Record 29 of Set 11 | caravelas
# Processing Record 30 of Set 11 | aykhal
# Processing Record 31 of Set 11 | vicuna
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | viedma
# Processing Record 34 of Set 11 | ozernovskiy
# Processing Record 35 of Set 11 | kushima
# Processing Record 36 of Set 11 | yate
# Processing Record 37 of Set 11 | barcelos
# Processing Record 38 of Set 11 | bourail
# Processing Record 39 of Set 11 | takoradi
# Processing Record 40 of Set 11 | san carlos de bariloche
# Processing Record 41 of Set 11 | noumea
# Processing Record 42 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 11 | orange cove
# Processing Record 44 of Set 11 | alakurtti
# Processing Record 45 of Set 11 | nyurba
# Processing Record 46 of Set 11 | lompoc
# Processing Record 47 of Set 11 | sao joao da barra
# Processing Record 48 of Set 11 | glazov
# Processing Record 49 of Set 11 | dickinson
# Processing Record 50 of Set 11 | rio grande
# Processing Record 1 of Set 12 | santo antonio de posse
# Processing Record 2 of Set 12 | launceston
# Processing Record 3 of Set 12 | san policarpo
# Processing Record 4 of Set 12 | jiexiu
# Processing Record 5 of Set 12 | natitingou
# Processing Record 6 of Set 12 | san quintin
# Processing Record 7 of Set 12 | mbuji-mayi
# Processing Record 8 of Set 12 | umarga
# Processing Record 9 of Set 12 | bulgan
# Processing Record 10 of Set 12 | luzhou
# Processing Record 11 of Set 12 | verkhnyaya inta
# Processing Record 12 of Set 12 | agde
# Processing Record 13 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 12 | dubna
# Processing Record 15 of Set 12 | tshikapa
# Processing Record 16 of Set 12 | najran
# Processing Record 17 of Set 12 | ugra
# Processing Record 18 of Set 12 | westport
# Processing Record 19 of Set 12 | kuala kedah
# Processing Record 20 of Set 12 | polson
# Processing Record 21 of Set 12 | pozo colorado
# Processing Record 22 of Set 12 | arco
# Processing Record 23 of Set 12 | rexburg
# Processing Record 24 of Set 12 | yamethin
# Processing Record 25 of Set 12 | itarema
# Processing Record 26 of Set 12 | isugod
# Processing Record 27 of Set 12 | aksu
# Processing Record 28 of Set 12 | ostruznica
# Processing Record 29 of Set 12 | aktash
# Processing Record 30 of Set 12 | popondetta
# Processing Record 31 of Set 12 | ati
# Processing Record 32 of Set 12 | le vauclin
# Processing Record 33 of Set 12 | amarillo
# Processing Record 34 of Set 12 | kurtamysh
# Processing Record 35 of Set 12 | uetendorf
# Processing Record 36 of Set 12 | boisar
# Processing Record 37 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 12 | cumberland
# Processing Record 39 of Set 12 | sobolevo
# Processing Record 40 of Set 12 | ostrovnoy
# Processing Record 41 of Set 12 | afonino
# Processing Record 42 of Set 12 | sadabad
# Processing Record 43 of Set 12 | diego de almagro
# Processing Record 44 of Set 12 | lima
# Processing Record 45 of Set 12 | derzhavinsk
# Processing Record 46 of Set 12 | tucumcari
# Processing Record 47 of Set 12 | hit
# Processing Record 48 of Set 12 | araouane
# Processing Record 49 of Set 12 | iwanai
# Processing Record 50 of Set 12 | zamboanguita
# Processing Record 1 of Set 13 | vostok
# Processing Record 2 of Set 13 | talaya
# Processing Record 3 of Set 13 | mocuba
# Processing Record 4 of Set 13 | vyazemskiy
# Processing Record 5 of Set 13 | winnemucca
# Processing Record 6 of Set 13 | leeds
# Processing Record 7 of Set 13 | tondano
# Processing Record 8 of Set 13 | yaan
# Processing Record 9 of Set 13 | anshun
# Processing Record 10 of Set 13 | mersing
# Processing Record 11 of Set 13 | lushunkou
# City not found. Skipping...
# Processing Record 12 of Set 13 | lasa
# Processing Record 13 of Set 13 | viota
# Processing Record 14 of Set 13 | talnakh
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | young
# Processing Record 17 of Set 13 | venado tuerto
# Processing Record 18 of Set 13 | comarapa
# Processing Record 19 of Set 13 | raul soares
# Processing Record 20 of Set 13 | kysyl-syr
# Processing Record 21 of Set 13 | fereydun kenar
# Processing Record 22 of Set 13 | sozopol
# Processing Record 23 of Set 13 | ardatov
# Processing Record 24 of Set 13 | bucak
# Processing Record 25 of Set 13 | gravdal
# Processing Record 26 of Set 13 | kutum
# Processing Record 27 of Set 13 | monte alegre
# Processing Record 28 of Set 13 | tateyama
# Processing Record 29 of Set 13 | hawkesbury
# Processing Record 30 of Set 13 | vanimo
# Processing Record 31 of Set 13 | nantucket
# Processing Record 32 of Set 13 | mariental
# Processing Record 33 of Set 13 | quelimane
# Processing Record 34 of Set 13 | santa cruz del norte
# Processing Record 35 of Set 13 | moyale
# Processing Record 36 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 13 | pierre
# Processing Record 38 of Set 13 | bauchi
# Processing Record 39 of Set 13 | denpasar
# Processing Record 40 of Set 13 | teya
# Processing Record 41 of Set 13 | vestmannaeyjar
# Processing Record 42 of Set 13 | arman
# Processing Record 43 of Set 13 | ilave
# Processing Record 44 of Set 13 | dir
# Processing Record 45 of Set 13 | gushikawa
# Processing Record 46 of Set 13 | bahia honda
# Processing Record 47 of Set 13 | marawi
# Processing Record 48 of Set 13 | pergamino
# Processing Record 49 of Set 13 | havre
# Processing Record 50 of Set 13 | bethanien
# Processing Record 1 of Set 14 | bilma
# Processing Record 2 of Set 14 | tosya
# Processing Record 3 of Set 14 | manono
# Processing Record 4 of Set 14 | ginir
# Processing Record 5 of Set 14 | crossville
# Processing Record 6 of Set 14 | khon kaen
# Processing Record 7 of Set 14 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 14 | wamba
# Processing Record 9 of Set 14 | santa isabel do rio negro
# Processing Record 10 of Set 14 | pervoye maya
# Processing Record 11 of Set 14 | ladybrand
# Processing Record 12 of Set 14 | waddan
# Processing Record 13 of Set 14 | harwich
# Processing Record 14 of Set 14 | santa vitoria do palmar
# Processing Record 15 of Set 14 | tokur
# Processing Record 16 of Set 14 | auray
# Processing Record 17 of Set 14 | itoman
# Processing Record 18 of Set 14 | honningsvag
# Processing Record 19 of Set 14 | patan
# Processing Record 20 of Set 14 | ialibu
# Processing Record 21 of Set 14 | tucuma
# Processing Record 22 of Set 14 | sinyavskoye
# Processing Record 23 of Set 14 | jasper
# Processing Record 24 of Set 14 | la ronge
# Processing Record 25 of Set 14 | luena
# Processing Record 26 of Set 14 | qaqortoq
# Processing Record 27 of Set 14 | marsh harbour
# Processing Record 28 of Set 14 | jodiya
# Processing Record 29 of Set 14 | dudinka
# Processing Record 30 of Set 14 | panji
# Processing Record 31 of Set 14 | sungai siput utara
# City not found. Skipping...
# Processing Record 32 of Set 14 | san salvo
# Processing Record 33 of Set 14 | zhongshu
# Processing Record 34 of Set 14 | kapoeta
# Processing Record 35 of Set 14 | mataram
# Processing Record 36 of Set 14 | negara
# Processing Record 37 of Set 14 | ahuimanu
# Processing Record 38 of Set 14 | yangcun
# Processing Record 39 of Set 14 | bechet
# Processing Record 40 of Set 14 | banjar
# Processing Record 41 of Set 14 | korla
# Processing Record 42 of Set 14 | sherpur
# Processing Record 43 of Set 14 | sann
# Processing Record 44 of Set 14 | mangaratiba
# Processing Record 45 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 14 | ust-kuyga
# Processing Record 47 of Set 14 | puri
# Processing Record 48 of Set 14 | mandera
# Processing Record 49 of Set 14 | novoselitskoye
# Processing Record 50 of Set 14 | el ejido
# Processing Record 1 of Set 15 | nushki
# Processing Record 2 of Set 15 | steinbach
# Processing Record 3 of Set 15 | cartagena
# Processing Record 4 of Set 15 | fairbanks
# Processing Record 5 of Set 15 | kurchum
# Processing Record 6 of Set 15 | ajdabiya
# Processing Record 7 of Set 15 | sinnamary
# Processing Record 8 of Set 15 | kenai
# Processing Record 9 of Set 15 | sechura
# Processing Record 10 of Set 15 | barranca
# Processing Record 11 of Set 15 | tete
# Processing Record 12 of Set 15 | avera
# Processing Record 13 of Set 15 | miles city
# Processing Record 14 of Set 15 | wageningen
# Processing Record 15 of Set 15 | chabahar
# Processing Record 16 of Set 15 | iraquara
# Processing Record 17 of Set 15 | gaogou
# Processing Record 18 of Set 15 | pariquera-acu
# City not found. Skipping...
# Processing Record 19 of Set 15 | vagur
# Processing Record 20 of Set 15 | katav-ivanovsk
# Processing Record 21 of Set 15 | cayenne
# Processing Record 22 of Set 15 | nyuksenitsa
# Processing Record 23 of Set 15 | uspantan
# Processing Record 24 of Set 15 | sierra vista
# Processing Record 25 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 26 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 15 | balkanabat
# Processing Record 28 of Set 15 | bandarbeyla
# Processing Record 29 of Set 15 | santa rosa
# Processing Record 30 of Set 15 | burica
# City not found. Skipping...
# Processing Record 31 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 15 | ponta delgada
# Processing Record 33 of Set 15 | bengkulu
# Processing Record 34 of Set 15 | karibib
# Processing Record 35 of Set 15 | kamina
# Processing Record 36 of Set 15 | tobe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     73.22        70         100
# 1             Yako      BF  12.9667   -2.2667     73.60        85          46
# 2             Hilo      US  19.7297 -155.0900     78.53        85          90
# 3       Butaritari      KI   3.0707  172.7902     82.49        71           8
# 4           Hobart      AU -42.8794  147.3294     54.10        62          40
# 5           Muroto      JP  33.2833  134.1500     81.90        72           2
# 6          Ushuaia      AR -54.8000  -68.3000     49.66        50          90
# 7          Biltine      TD  14.5333   20.9167     78.40        70          99
# 8            Kapaa      US  22.0752 -159.3190     82.38        76          90
# 9          Messina      IT  38.1933   15.5497     82.65        61           0
#
#    Wind Speed Current Description
# 0       23.42          light rain
# 1        6.58    scattered clouds
# 2        5.75       moderate rain
# 3        8.97          light rain
# 4        5.01    scattered clouds
# 5        8.30           clear sky
# 6       19.57     overcast clouds
# 7        8.61     overcast clouds
# 8        3.00     overcast clouds
# 9        4.00           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
